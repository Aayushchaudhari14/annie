# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="whitegrid")

# %%
df=pd.read_csv('heart_cleveland_upload.csv')

# %%
df.shape
# Out:
# (297, 14)

# %%
df.head()
# Out:
#    age  sex  cp trestbps  chol  fbs  restecg thalach  exang oldpeak  slope  \
# 0   69    1   0      160   234    1        2     131      0     0.1      1
# 1   69    0   0      140   239    0        0     151      0       ?      0
# 2   66    0   0        ?   226    0        0     114      0     2.6      2
# 3   65    1   0      138   282    1        2     174      0     1.4      1
# 4   64    1   0      110   211    0        2       ?      1     1.8      1
#
#    ca  thal  condition
# 0   1     0          0
# 1   2     0          0
# 2   0     0          0
# 3   1     0          1
# 4   0     0          0

# %%
df.hist(figsize=(15,10),color='skyblue',edgecolor='black')
plt.suptitle("Histogram of Heart Disease Dataset Features' Numeric Distribution",fontsize=16)
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.scatterplot(data=df, x='age', y='thalach', hue='condition', palette='Set1')
plt.title('Scatter Plot: Age vs Max Heart Rate (colored by Target)')
plt.xlabel('Age')
plt.ylabel('Max Heart Rate (thalach)')
plt.show()

# %%
sns.stripplot(data=df,x='chol',jitter=True)
plt.title('Dot Plot of Cholestrol')
plt.xlabel('Cholestrol')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df,x='cp',palette='coolwarm')
plt.title('Bar Plot of Chest Pain Types')
plt.xlabel('Chest Pain Type')
plt.ylabel('No of cases experiencing the pain')
plt.show()
# Out:
# C:\Users\bhand\AppData\Local\Temp\ipykernel_35084\1349623390.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df,x='cp',palette='coolwarm')

# %%
df_sorted=df.sort_values(by='age')
plt.figure(figsize=(10,6))
plt.plot(df_sorted['age'],df_sorted['chol'],marker='o',color='red')
plt.title('Line Chart of Age vs Cholesterol')
plt.xlabel('Age')
plt.ylabel('Cholestrol')
plt.grid(True)
plt.show()

# %%
target_counts=df['condition'].value_counts()
labels=['No Disease','Disease']
colors=['red','blue']
plt.figure(figsize=(6,8))
plt.pie(target_counts,labels=labels,autopct='%1.1f%%',startangle=140,colors=colors)
plt.title('Heart Disease Distribution')
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.boxplot(x='condition',y='chol',data=df,palette='pastel')
plt.title('Boxplot of Cholesterol by Heart Disease')
plt.xlabel('Heart Disease')
plt.ylabel('Cholesterol')
plt.show()
# Out:
# C:\Users\bhand\AppData\Local\Temp\ipykernel_35084\2007259800.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='condition',y='chol',data=df,palette='pastel')

# %%
# Objective: Combine visualizations to gain a detailed insight into distributions and outliers (compact version)

# Example: Boxplot + Histogram + Scatter for 'thalach' (max heart rate)
fig, ax = plt.subplots(3, 1, figsize=(8, 9), gridspec_kw={'height_ratios': [1, 2, 2]})

# Boxplot
sns.boxplot(data=df, x='thalach', ax=ax[0], color='lightblue')
ax[0].set_title('Boxplot of Max Heart Rate')

# Histogram
sns.histplot(df['thalach'], bins=20, kde=True, ax=ax[1], color='salmon')
ax[1].set_title('Histogram of Max Heart Rate')

# Scatter plot (vs age for context)
sns.scatterplot(data=df, x='thalach', y='age', hue='condition', palette='Set1', ax=ax[2])
ax[2].set_title('Scatter Plot: Age vs Max Heart Rate (Colored by Target)')

plt.tight_layout()
plt.show()
